# %%
import numpy as np
import pymc3 as pm
import arviz as az
import pandas as pd

# %%
durations = np.random.exponential(scale=10.0, size=1000)

# %%
durations
# Out:
# array([3.12278307e+00, 1.72789743e+01, 4.92576143e+00, 1.02693843e+01,
#        4.66048666e+00, 6.58440919e+00, 1.54233856e+01, 6.41490676e+00,
#        2.59605809e+01, 4.87234645e+00, 3.57784635e-01, 3.14453709e+00,
#        8.44080171e+00, 3.84532874e+00, 7.08484659e+00, 1.07864027e+01,
#        4.69499640e+00, 1.56975931e+01, 5.35238024e-01, 2.41651599e+01,
#        6.28649496e+00, 2.75133726e+01, 7.26969937e+00, 1.26124052e+00,
#        2.90052353e+01, 2.92938637e+01, 2.03062394e+01, 1.28334983e+01,
#        6.68741124e+00, 4.07520339e+00, 1.55493546e+01, 2.33410220e+00,
#        7.03581768e+00, 1.02769494e+01, 5.01197527e+00, 1.17390457e+01,
#        3.08668915e+01, 4.95247010e+00, 1.21020948e+01, 9.31258921e+00,
#        2.25156395e+01, 1.44387379e+01, 2.58634636e+01, 8.14174232e+00,
#        4.73231046e+00, 1.01982431e+01, 3.21393047e+00, 7.89675268e+00,
#        4.20645097e+00, 1.76579528e+01, 7.95947519e+00, 1.04904820e+01,
#        3.66248165e+00, 2.62302139e+00, 1.22599191e+01, 1.72799948e+00,
#        7.59145842e+00, 1.66658426e+01, 1.94137464e+01, 9.01118334e+00,
#        1.03695349e+01, 2.95565044e+00, 3.71767950e+00, 1.33829377e+00,
#        5.98378679e+00, 3.35048252e+00, 1.11014743e+01, 1.98785693e+01,
#        2.06483028e+00, 1.28437674e+00, 5.53381548e+00, 5.13154013e-01,
#        7.33802287e-01, 1.88442451e+01, 1.36542857e+01, 2.79049235e+00,
#        1.42417233e+01, 2.23532291e+01, 5.79344943e+00, 2.14160608e+00,
#        7.04471254e+00, 1.15480243e+01, 1.99932534e+00, 8.15328716e-01,
#        7.98342799e+00, 2.99456070e+00, 1.87138694e+00, 2.28736548e-01,
#        1.28303297e+00, 1.57867842e+01, 8.24025305e+00, 1.44832418e+00,
#        7.06828148e+00, 1.83162645e+01, 1.29756260e+01, 6.07387652e+00,
#        8.28453501e+00, 9.10518482e-01, 2.13622129e+01, 1.20421240e+00,
#        1.42508292e+00, 6.40702729e+00, 1.37596665e+00, 9.46724193e+00,
#        1.92899519e+00, 1.01949511e+00, 6.56483856e+00, 6.79449620e+00,
#        2.47001470e+01, 9.30431662e+00, 6.27014477e+00, 2.95951878e+00,
#        2.49462194e+01, 1.46030288e+01, 4.12176094e+00, 2.56579652e+01,
#        8.67757462e+00, 1.01078455e+01, 7.41235287e+00, 8.62363854e+00,
#        9.35701796e+00, 7.45942068e+00, 2.88899111e+00, 1.74790015e+00,
#        3.92383173e+00, 8.57877228e+00, 1.16734926e+01, 5.85121945e+00,
#        1.40620630e+01, 4.60027499e+00, 9.56947308e+00, 1.47051358e+01,
#        5.05755159e+00, 4.10452262e+00, 3.75408980e-01, 1.49864801e+01,
#        2.22262083e+01, 1.44701437e+01, 1.23681852e+01, 1.23724062e+01,
#        2.48471324e+00, 8.84508678e+00, 7.90381852e+00, 3.69397703e+00,
#        8.40353874e+00, 1.50761644e+01, 3.33543646e+01, 2.84930486e+01,
#        2.36748484e+01, 3.80323013e+00, 2.58890951e+01, 2.56049734e+01,
#        3.37343964e+00, 1.19117262e+01, 1.08003657e+01, 1.67848502e+00,
#        1.72536084e+00, 2.45491998e+01, 1.40188900e+01, 8.63098826e+00,
#        4.86044728e+00, 1.78484939e+01, 1.69392432e+00, 1.10925576e+01,
#        5.17944725e+00, 1.03797999e+01, 2.33203628e+00, 6.18512456e+00,
#        1.54359506e+00, 3.97790039e+00, 1.59428948e+01, 9.86417178e+00,
#        2.58380032e+01, 2.24827272e+01, 5.98184339e+00, 5.55903120e+00,
#        5.17910230e+00, 1.10042592e+01, 2.28661168e+01, 5.83278103e+00,
#        1.71292572e+01, 1.71557531e+01, 2.07022305e+01, 6.92944128e+00,
#        7.98073060e-01, 5.75480050e+00, 4.00119474e+00, 2.39625025e+01,
#        1.48500112e+01, 1.44976834e+01, 6.51102076e+00, 1.03802976e+01,
#        3.64054245e+00, 4.32200263e+00, 7.73999160e-01, 2.33470100e+01,
#        2.34659025e+00, 5.94200011e+00, 1.04718037e+01, 8.78269423e-01,
#        3.11512974e+01, 2.28715491e-01, 9.41344365e-01, 5.21976591e+00,
#        1.17805973e+01, 6.67683058e+00, 5.28242452e+00, 4.09542524e+00,
#        1.64366775e+01, 1.36969861e-01, 1.86965896e+01, 4.14406416e+01,
#        7.18861859e-01, 5.52974938e-01, 4.97870015e+00, 3.23013746e+00,
#        6.04517949e+00, 9.72057646e+00, 5.56550729e+00, 3.03173420e+01,
#        5.97122597e+00, 1.27885067e+01, 3.05329234e+01, 1.15622660e+01,
#        9.99584056e+00, 3.67861542e-01, 1.11431386e+01, 9.13724590e+00,
#        2.98440687e+01, 1.10166832e+01, 8.39314290e+00, 7.83362436e+00,
#        1.84012035e-01, 4.00530545e+00, 4.84914743e-01, 1.41154813e-01,
#        7.40852533e+00, 2.21155145e+01, 1.16686599e+00, 1.59890970e+01,
#        4.19401667e+00, 1.59458680e+01, 6.38653265e+00, 9.76252798e+00,
#        2.95013589e+00, 3.55000408e+00, 1.41434708e+01, 9.81807425e+00,
#        2.73029698e+01, 2.90122583e+01, 1.02291847e+01, 1.64931363e+01,
#        7.50689344e+00, 2.02139638e+01, 1.21303089e+01, 3.55980643e+00,
#        1.54748470e+01, 1.32474835e+01, 5.78430844e+00, 5.01321628e-01,
#        1.81685933e+01, 4.47113593e+00, 2.84578610e-01, 5.48963141e+00,
#        5.41453416e+00, 8.37955519e+00, 4.98696996e+00, 1.03579666e+01,
#        4.21104183e+00, 6.75003053e+00, 1.10985048e+01, 2.53207585e+01,
#        3.79281919e+00, 2.46816857e+00, 1.93751861e+01, 4.54797938e+00,
#        1.39287095e+01, 6.70365147e+00, 7.13324074e-01, 6.80027591e+00,
#        2.41329697e+01, 3.17083502e+01, 1.26807883e+01, 2.08605847e+01,
#        3.90451009e+00, 4.83013616e+00, 6.33409628e+00, 5.55860076e+00,
#        9.38687403e-01, 3.39932728e+01, 4.83569584e+00, 8.62607102e+00,
#        1.24523273e+00, 8.53763695e+00, 1.40493360e+01, 9.31073626e+00,
#        2.96163940e+01, 6.22061700e+00, 2.30549229e+01, 1.74416036e+01,
#        3.78623444e+01, 3.81879238e+01, 1.49909327e+01, 3.38566867e+00,
#        4.58069415e+00, 8.28455083e+00, 2.23614532e+00, 4.56411044e+00,
#        2.66642709e+01, 7.74599626e-01, 1.98435091e+01, 7.77380648e-01,
#        6.12092676e+00, 1.25617280e+00, 5.95992825e+00, 4.72445884e-01,
#        9.89727651e+00, 2.94574190e+00, 8.36322237e+00, 1.45709374e+01,
#        1.43979397e+01, 1.99989551e+00, 6.50612744e+00, 1.17058669e+01,
#        3.56234423e+00, 3.80967930e+01, 4.30278690e+01, 8.56301910e+00,
#        8.38939661e-01, 1.05485860e+01, 1.33435956e+01, 1.99126355e+01,
#        1.19924440e+01, 4.77475083e+01, 2.76517035e+00, 3.30696752e+00,
#        1.34943609e+01, 1.74101601e+01, 1.47341909e+01, 1.05049315e+01,
#        2.74596879e+00, 2.06854778e+01, 3.62136466e+00, 3.80423031e+00,
#        2.84986007e+01, 1.67514683e+00, 7.59330488e+00, 1.26507663e+00,
#        5.06146366e+00, 1.08105995e+01, 8.03266703e+00, 3.88377922e+00,
#        5.48854785e-01, 2.13067609e+00, 1.05754409e+01, 1.24403699e+00,
#        6.12984301e+00, 1.45406003e+01, 4.75121716e+00, 1.48664288e+00,
#        5.25826203e-02, 1.36900315e+01, 3.29001210e-01, 5.11507465e+00,
#        5.21947772e+00, 2.58995814e+00, 2.80921941e+01, 3.92529162e+00,
#        6.71217668e-01, 1.05856128e+01, 6.02909923e+00, 5.17023790e+00,
#        1.83932756e+00, 6.11301563e+00, 1.42527057e+01, 1.39010255e+00,
#        1.65165946e+01, 5.31002160e+00, 1.05292289e+01, 2.48292913e+01,
#        1.64608789e+01, 1.94072541e+01, 2.91508246e+00, 2.03943240e+00,
#        1.02796322e+01, 1.61283477e-01, 1.17833529e+01, 4.16964673e+00,
#        7.53017818e-01, 1.26393437e+01, 1.47445778e+01, 2.96322048e+00,
#        5.46665938e+00, 2.52498039e+01, 5.69518799e-01, 2.34454180e-01,
#        6.58983214e-01, 2.23365660e+01, 3.89415060e-01, 3.60400421e+00,
#        2.34645072e+00, 9.02309212e+00, 8.01127189e+00, 6.60941382e+00,
#        5.22781719e+00, 4.81369590e+00, 1.84615298e+01, 7.97273504e+00,
#        8.53758869e-01, 6.17931774e+00, 1.13560651e+01, 3.24179652e+00,
#        1.72400580e+01, 2.28700914e+01, 1.39966156e+01, 1.03292866e+00,
#        1.23315086e+01, 3.95537384e+00, 6.43409912e+00, 2.11896698e+01,
#        6.70539845e+00, 1.14218566e+01, 1.09787507e+01, 2.03117694e+00,
#        6.47162130e+00, 3.84911188e+00, 3.84717806e+00, 1.38304790e+00,
#        1.79540400e+01, 1.21875210e+01, 2.00280002e+00, 9.95790227e+00,
#        2.98225074e+00, 8.28633307e+00, 2.64304409e+01, 1.13008571e+01,
#        6.02784174e+00, 2.56977013e+00, 9.81414965e+00, 1.80268999e+01,
#        3.35599521e+00, 3.62310639e+00, 6.13958251e+00, 1.79176268e+01,
#        1.06098800e+01, 1.21988737e+01, 1.77177721e+01, 1.07809818e+01,
#        3.45440995e-01, 5.73021274e+00, 8.50326966e+00, 2.42624868e+00,
#        3.89457290e+00, 2.52749576e-01, 1.04949333e+01, 2.47674290e+00,
#        8.60328496e-01, 2.26881655e+00, 4.89668950e+00, 2.22632573e+01,
#        3.92387194e+00, 1.87760574e+00, 1.74069129e+01, 5.63083159e+00,
#        5.93403623e+00, 1.28984776e+01, 4.52708479e+00, 6.68849745e-01,
#        3.42730198e-01, 2.70758536e+01, 1.32244135e+01, 8.77278774e+00,
#        3.06595418e+00, 1.37727253e+01, 2.18363867e+00, 2.98982673e+01,
#        3.64844431e+00, 5.00946695e+00, 1.15109124e+01, 4.64897724e+00,
#        8.35658611e+00, 1.43409001e+01, 5.30214941e-01, 3.27689898e+00,
#        6.46541363e+00, 6.47190091e+00, 6.74689877e+00, 1.61822129e+01,
#        2.49670833e+00, 1.00613138e+00, 8.32322904e+00, 7.40991294e+00,
#        1.71501943e+01, 6.03641038e-01, 7.54904580e+00, 3.71374708e+00,
#        1.57113318e+00, 2.50091757e+00, 2.76165364e+00, 1.31924357e+01,
#        4.27584338e+00, 1.02174668e+00, 7.54557538e+00, 1.57430860e+01,
#        1.58922484e+01, 2.39356899e+01, 1.50040469e+01, 9.56271249e+00,
#        1.72126429e+01, 1.72673809e+01, 2.35632635e+01, 9.37875878e+00,
#        1.19920330e+01, 1.21924373e+01, 9.87755899e-01, 1.21877999e+01,
#        1.20379937e+00, 9.01381329e-01, 1.42360129e+00, 1.96103965e+00,
#        3.54953126e+00, 1.74553406e+01, 3.11737408e-01, 4.19274513e+00,
#        2.64712392e+00, 1.03725064e+01, 1.76543632e+00, 6.84314328e+00,
#        1.07567905e+01, 1.85513556e+01, 6.01840550e-01, 1.24410646e+01,
#        3.55497212e+00, 1.60271970e+01, 5.98523308e+01, 2.86367310e+01,
#        1.39423353e+01, 5.41477512e+00, 3.13392940e+00, 2.23533122e+01,
#        2.21034314e+00, 6.89698288e+00, 2.84974759e+00, 1.39049759e+01,
#        9.01230642e+00, 9.79076593e+00, 4.27393770e+00, 8.32065569e-01,
#        2.38064933e+01, 2.00226496e+01, 9.56966413e-01, 3.17549855e+01,
#        2.28217307e+01, 1.27021785e+00, 6.90255603e+00, 1.07130883e+01,
#        4.67935730e+00, 9.04480226e+00, 1.61412781e+01, 2.11046656e+01,
#        8.24350511e+00, 3.74111160e-01, 2.00901570e+00, 7.23593610e+00,
#        2.23063746e+01, 9.50789795e+00, 4.90438539e+00, 9.25783996e+00,
#        4.86827691e+00, 5.00032804e+00, 2.71165650e+01, 3.28320415e+01,
#        1.30548278e+01, 9.55678499e+00, 3.97530323e-05, 1.19838283e+01,
#        7.64192659e-01, 1.02996086e+00, 9.56109559e+00, 9.37096734e+00,
#        2.54925378e+01, 8.27927356e-01, 2.71669032e+00, 1.38325129e+00,
#        9.26231562e+00, 2.17799954e+01, 2.76878531e+00, 1.24646135e+01,
#        9.23848443e+00, 1.25540217e+01, 6.69487693e+00, 5.28638419e+00,
#        4.57006856e+00, 3.87476375e+00, 8.49821593e+00, 4.66228653e+01,
#        1.40650899e+01, 2.14037323e+00, 8.35034171e+00, 9.07724875e+00,
#        1.61204130e+01, 3.53771770e+00, 1.01410086e+00, 4.45134640e+00,
#        8.87037876e+00, 1.02218149e+00, 2.57460307e+01, 2.14399956e+01,
#        5.81914360e+00, 1.23615282e+01, 1.92422899e+01, 3.51133738e+01,
#        4.58964237e+00, 1.62652417e+01, 1.31783796e+01, 9.81211147e+00,
#        5.73941131e+00, 1.58561603e+01, 6.10532714e+00, 1.13419340e+00,
#        2.32678529e+00, 6.64691997e+00, 6.54638949e+00, 2.71960451e+01,
#        2.95366450e+00, 1.32731851e+01, 2.66925775e+01, 8.41338814e+00,
#        7.67907621e+00, 2.38381694e+00, 4.42228512e+00, 9.95249390e+00,
#        1.48428979e+01, 1.92189730e+00, 7.69429871e+00, 3.39267386e+00,
#        4.22349679e+00, 4.23015055e+01, 2.86103720e-01, 1.06724740e+01,
#        2.79276941e+00, 5.63546806e+00, 7.44867444e+00, 7.20690637e+00,
#        7.16664013e+00, 6.52827043e+00, 1.25381308e+00, 1.12033950e+00,
#        1.23461617e+01, 5.86267078e+00, 2.43729813e-01, 2.93875332e+01,
#        1.14890539e+01, 9.93152074e+00, 4.05995008e+00, 2.39367045e+00,
#        7.73085108e-01, 2.67232581e+00, 2.08150685e+01, 4.39515954e+00,
#        1.58638891e+01, 2.26024183e+01, 4.76560478e-01, 3.58397587e+01,
#        2.22535014e+01, 9.36806828e+00, 4.73963675e+00, 1.03129244e+01,
#        1.59307817e+01, 5.50876161e+00, 3.49076388e+00, 1.48487942e+01,
#        3.07670800e-01, 1.49966065e+01, 1.43660229e+00, 6.10151194e+00,
#        5.47085460e+00, 1.61308642e+01, 2.17190577e+01, 2.55849120e+01,
#        3.58878201e+00, 1.95198344e+00, 1.77280225e-01, 1.38718835e+01,
#        1.11176392e+01, 2.59002155e+00, 5.28528565e+00, 1.37804114e+01,
#        1.38899428e+01, 1.59104784e+01, 3.14072719e+00, 1.51647669e+01,
#        1.07377683e+01, 3.14423440e+01, 2.76319057e+01, 4.50241268e+00,
#        2.96685922e+01, 2.49304195e+00, 9.78291404e+00, 1.63496041e+00,
#        1.78470788e+01, 1.09310103e+01, 1.37457952e+00, 2.57180026e+00,
#        2.94966498e+01, 1.42665271e+01, 3.54551474e+00, 4.09707970e+00,
#        2.55193111e-01, 2.22573855e+00, 2.53585450e+00, 1.48145367e+00,
#        1.80213396e+00, 1.68197262e+01, 2.07350523e+01, 1.01871190e+00,
#        8.20695533e-02, 3.44759498e-01, 3.33630224e+00, 2.00615268e+01,
#        5.14088710e+00, 3.28200780e+00, 3.33376304e+01, 3.08226383e+00,
#        3.34001298e+00, 2.42029992e+01, 1.23022275e+01, 1.44649921e+01,
#        1.71120625e+01, 2.40268480e+00, 2.36780538e+01, 1.42252904e+01,
#        1.13872987e+01, 1.82149923e+01, 4.42068346e+00, 7.50834697e+00,
#        1.88614764e+00, 1.31552016e+01, 1.42616295e+00, 7.62093163e+00,
#        1.62297079e+01, 3.29524477e+01, 1.62331543e+01, 9.42924839e+00,
#        1.38354060e+00, 1.70022134e+01, 1.32504247e+00, 1.02499949e+00,
#        1.42613340e+01, 5.99346913e+00, 5.28863918e-01, 2.07294651e+00,
#        5.51923676e-01, 4.40882025e+00, 8.29276588e+00, 2.90977670e+00,
#        1.00656812e+01, 2.15705456e+00, 6.26976304e-01, 7.78203376e+00,
#        8.58523082e+00, 8.34499810e+00, 9.89562692e+00, 1.12001294e-01,
#        1.46732919e+01, 1.44045788e+01, 1.74087692e+00, 1.02941331e-02,
#        3.06542984e-01, 4.22280242e+00, 7.56276743e+00, 9.11169982e+00,
#        3.38163235e+00, 5.82042844e+01, 1.16840114e+01, 2.56655070e+01,
#        2.96349778e+01, 7.66758291e+00, 2.26663468e+01, 8.55236505e+00,
#        1.51810396e+01, 1.18026483e+01, 4.25794721e+00, 6.49724524e+00,
#        5.33384122e-01, 3.02948392e+00, 2.75711824e+00, 3.15580111e+01,
#        6.66755750e+00, 2.87274512e+00, 6.63010317e+00, 5.26060862e+00,
#        2.03338451e+01, 5.80578716e+00, 5.37416840e-01, 7.54265560e+00,
#        1.81445630e+01, 2.75206853e+01, 1.97162277e+00, 2.04979106e+01,
#        9.80585339e+00, 2.18638151e+01, 5.53938606e+00, 6.44941511e+00,
#        2.75772304e-01, 3.43244913e-02, 3.64312974e+00, 6.24672647e+00,
#        5.41889575e+00, 1.46078822e+01, 1.05128056e+01, 1.57439177e+00,
#        3.11774780e+01, 2.79169150e+01, 2.89491675e+01, 9.28574368e+00,
#        1.96010146e+01, 4.81696181e+00, 6.68372028e+00, 6.68017878e+00,
#        5.06197088e+00, 3.16925676e-01, 2.82190004e+01, 1.37810147e+00,
#        3.89606879e-01, 4.61095687e+01, 7.38950791e+00, 3.25689863e+00,
#        8.83145859e+00, 1.60465462e-01, 7.91316428e+00, 4.41209421e+00,
#        1.17847068e+00, 1.38337136e+01, 9.28862696e+00, 3.40726448e+00,
#        8.98672209e+00, 3.65074178e+01, 3.51368924e+00, 7.79185710e+00,
#        1.67491017e+00, 1.64900903e+01, 9.66412979e-01, 2.33402867e+00,
#        2.58432595e+00, 2.84700811e+01, 1.21802884e-01, 1.95301217e+01,
#        1.53571616e+00, 8.01478734e+00, 7.49201380e+00, 8.50700546e+00,
#        7.52813514e-01, 1.60629484e+01, 3.32615197e+01, 1.15046375e+00,
#        7.75138369e+00, 6.18007722e+00, 1.66744141e+00, 4.74620960e+00,
#        2.28509431e+00, 5.02394890e+00, 1.59743523e+01, 1.27898931e+00,
#        1.04617608e+01, 2.00750692e+01, 4.27548935e+00, 4.30385371e+00,
#        2.92921554e+01, 1.43635294e+01, 2.68885258e+00, 4.79569822e+00,
#        9.89502876e+00, 2.23600502e+01, 1.91572156e+01, 1.27365623e+01,
#        3.74582242e+01, 2.65885633e+00, 4.72068254e-01, 1.57395977e+01,
#        5.52428147e+00, 4.39465764e+00, 3.03600426e+01, 1.13621913e+01,
#        2.70685569e-01, 2.57032215e+01, 5.54668371e+00, 1.51890016e+01,
#        1.03650528e+00, 7.49587315e+00, 1.11255389e+00, 2.65899140e+00,
#        1.20802472e+01, 1.87431450e+00, 3.13868254e+01, 1.35874255e+01,
#        1.28235741e+01, 6.84617335e+00, 4.07980979e+00, 1.66626139e+00,
#        2.52391435e+01, 5.89506184e+00, 2.00597437e+01, 1.86960520e+01,
#        3.42793495e+00, 4.33617920e+00, 1.63217375e-01, 8.08652124e+00,
#        1.47425249e+01, 9.39580916e+00, 4.30345245e+00, 5.29011596e+00,
#        2.98182735e+00, 2.02054117e+01, 3.86951925e+00, 9.95882216e+00,
#        1.74405876e+00, 2.24743853e+00, 1.56239328e+01, 3.05645363e+00,
#        3.92217678e+00, 1.52969645e+01, 3.05314389e+00, 4.44386902e+00,
#        2.19018680e+01, 1.26127741e+01, 2.21718105e+01, 2.35839523e+00,
#        2.70829517e+00, 5.27227029e+00, 1.04213231e+01, 3.18330567e+01,
#        6.27151700e+00, 3.92404242e+00, 6.69969646e+00, 5.83217154e+00,
#        1.24872492e+00, 2.36540911e+01, 3.97385415e+00, 4.01262065e+00,
#        3.01998167e+01, 1.10115716e+01, 2.57672577e+00, 3.55788180e+00,
#        1.82510748e+00, 4.36327099e-01, 1.35833587e+01, 1.97447310e+01,
#        7.06270222e+00, 2.10858930e+01, 1.42748044e+00, 9.92686272e-01,
#        2.56362679e+01, 1.18727445e+01, 1.47093536e+01, 5.91751767e+00,
#        2.18890849e+01, 1.75517354e+00, 1.26185068e+01, 5.95243976e-02,
#        1.79128174e+01, 4.96222851e+00, 1.51434521e+01, 3.31473112e+00,
#        2.36287375e+00, 5.39607337e-01, 1.30998330e+01, 1.39349880e+01,
#        1.60394784e+01, 1.53349596e+01, 4.77836319e+00, 2.20622817e+01,
#        2.29667404e+00, 5.05589965e+00, 3.04325080e+01, 9.04603116e+00,
#        1.75230360e+00, 1.46416385e+01, 5.56817406e+00, 9.60277604e+00,
#        1.53641228e+01, 2.84194374e+01, 1.22381878e-02, 1.26313346e+01,
#        4.11340010e+00, 2.00590625e+00, 1.05014872e+01, 2.40288341e-02,
#        2.12555546e+00, 1.59014982e+00, 3.05591933e+01, 5.39823406e+00,
#        3.37331021e-01, 7.19254045e+00, 3.48904952e+00, 1.44749418e+01,
#        1.62237201e+01, 1.15318146e+00, 3.74175178e-01, 2.97505065e+01])

# %%
s = pd.Series(durations)
s.describe()
# Out:
# count    1000.000000
# mean        9.859474
# std         9.015340
# min         0.000040
# 25%         3.063579
# 50%         7.053707
# 75%        14.346557
# max        59.852331
# dtype: float64

# %%
with pm.Model() as model:
    # TODO. Set the prior for the scale parameter.
    # TODO. Set the likelihood function.
    trace = pm.sample(5000, chains=2, random_seed=123)
# Out:
# /var/folders/4_/vrr8kzqn5b9dxsprxn13022m0000gn/T/ipykernel_63898/863237996.py:4: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(5000, chains=2, random_seed=123)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4_/vrr8kzqn5b9dxsprxn13022m0000gn/T/ipykernel_63898/863237996.py in <module>
#       2     # TODO. Set the prior for the scale parameter.
#       3     # TODO. Set the likelihood function.
# ----> 4     trace = pm.sample(5000, chains=2, random_seed=123)
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     488
#     489     if model.ndim == 0:
# --> 490         raise ValueError("The model does not contain any free variables.")
#     491
#     492     if step is None and init is not None and all_continuous(model.vars):
#
# ValueError: The model does not contain any free variables.

# %%
with model:
    az.plot_posterior(_)  # TODO. plot the posterior function
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4_/vrr8kzqn5b9dxsprxn13022m0000gn/T/ipykernel_63898/4070051928.py in <module>
#       1 with model:
# ----> 2     az.plot_posterior(_)
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/plots/posteriorplot.py in plot_posterior(data, var_names, filter_vars, transform, coords, grid, figsize, textsize, hdi_prob, multimodal, skipna, round_to, point_estimate, group, rope, ref_val, rope_color, ref_val_color, kind, bw, circular, bins, labeller, ax, backend, backend_kwargs, show, **kwargs)
#     214         >>> az.plot_posterior(data, var_names=['mu'], hdi_prob=.75)
#     215     """
# --> 216     data = convert_to_dataset(data, group=group)
#     217     if transform is not None:
#     218         data = transform(data)
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/data/converters.py in convert_to_dataset(obj, group, coords, dims)
#     177     xarray.Dataset
#     178     """
# --> 179     inference_data = convert_to_inference_data(obj, group=group, coords=coords, dims=dims)
#     180     dataset = getattr(inference_data, group, None)
#     181     if dataset is None:
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/data/converters.py in convert_to_inference_data(obj, group, coords, dims, **kwargs)
#     129             "cmdstanpy fit",
#     130         )
# --> 131         raise ValueError(
#     132             "Can only convert {} to InferenceData, not {}".format(
#     133                 ", ".join(allowable_types), obj.__class__.__name__
#
# ValueError: Can only convert xarray dataarray, xarray dataset, dict, netcdf filename, numpy array, pystan fit, pymc3 trace, emcee fit, pyro mcmc fit, numpyro mcmc fit, cmdstan fit csv filename, cmdstanpy fit to InferenceData, not Series

# %%
az.summary(_, hdi_prob=0.95) # TODO Get the summary statistics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4_/vrr8kzqn5b9dxsprxn13022m0000gn/T/ipykernel_63898/4140083750.py in <module>
# ----> 1 az.summary(_, hdi_prob=0.95) # TODO Get the summary statistics
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/stats/stats.py in summary(data, var_names, filter_vars, group, fmt, kind, round_to, circ_var_names, stat_funcs, extend, hdi_prob, skipna, labeller, coords, index_origin, order)
#    1185             dataset = data[group]
#    1186     else:
# -> 1187         dataset = convert_to_dataset(data, group="posterior")
#    1188     var_names = _var_names(var_names, dataset, filter_vars)
#    1189     dataset = dataset if var_names is None else dataset[var_names]
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/data/converters.py in convert_to_dataset(obj, group, coords, dims)
#     177     xarray.Dataset
#     178     """
# --> 179     inference_data = convert_to_inference_data(obj, group=group, coords=coords, dims=dims)
#     180     dataset = getattr(inference_data, group, None)
#     181     if dataset is None:
#
# ~/repo/Python/web-optimization/venv/lib/python3.9/site-packages/arviz/data/converters.py in convert_to_inference_data(obj, group, coords, dims, **kwargs)
#     129             "cmdstanpy fit",
#     130         )
# --> 131         raise ValueError(
#     132             "Can only convert {} to InferenceData, not {}".format(
#     133                 ", ".join(allowable_types), obj.__class__.__name__
#
# ValueError: Can only convert xarray dataarray, xarray dataset, dict, netcdf filename, numpy array, pystan fit, pymc3 trace, emcee fit, pyro mcmc fit, numpyro mcmc fit, cmdstan fit csv filename, cmdstanpy fit to InferenceData, not Series
